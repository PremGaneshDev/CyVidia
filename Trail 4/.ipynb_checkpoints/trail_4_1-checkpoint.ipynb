# %%
import pandas as pd

# Replace 'your_file_path' with the actual path to your Excel file
file_path = 'POC Based Requirements.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Now you have your data in the 'df' DataFrame
# pritn all the data
print(df)
# Out:
#      ReqNo                   Requirement Area        Requirements Bucket  \
# 0   ASLC.1               Application Security      Secure SDLC Lifecycle
# 1   ASLC.2               Application Security    Third Party Code Audits
# 2   ASLC.3               Application Security    Secure Coding Practices
# 3   ASLC.4               Application Security      Security Requirements
# 4   ASLC.5               Application Security    Environment segregation
# ..     ...                                ...                        ...
# 81  NMS.11  Network Management and \nSecurity        Firewall management
# 82   NMS.1  Network Management and \nSecurity  Network device management
# 83   NMS.2  Network Management and \nSecurity             Access control
# 84   NMS.3  Network Management and \nSecurity  Wireless network security
# 85   NMS.4  Network Management and \nSecurity       Network seggregation
#
#                               Requirement Description  \
# 0   Incorporate/Ensure information security across...
# 1   In respect of critical business applications, ...
# 2   Secure coding practices may also be implemente...
# 3   Besides business functionalities, security req...
# 4   The development, test and production environme...
# ..                                                ...
# 81  Firewall rules shall be defined to block unide...
# 82  Ensure that all the network devices are config...
# 83  The default passwords of all the network devic...
# 84  Put in appropriate controls to secure wireless...
# 85  Critical infrastructure of UCB (viz., NEFT, RT...
#
#                                             Key Words  Type  Source Type  \
# 0               Ensure, stage, application life cycle  Must  Regulations
# 1   Professionally, service providers, code audits...  Must  Regulations
# 2   secure, coding, practices, internally, applica...  Must  Regulations
# 3   security requirements, system development, imp...  Must  Regulations
# 4                             Environment, segregated  Must  Regulations
# ..                                                ...   ...          ...
# 81  firewall, outbound connections, reverse TCP sh...  Must  Regulations
# 82  Network Devices, configuration, periodically a...  Must  Regulations
# 83   Default Passwords, network devices, installation  Must  Regulations
# 84  wireless, LAN, access points, wireless client ...  Must  Regulations
# 85  Critical Infrastructure, NEFT, RTGS, SWIFT, CB...  Must  Regulations
#
#    Source                      Source Detail
# 0     RBI                 RBI - CS Framework
# 1     RBI                 RBI - CS Framework
# 2     RBI                 RBI - CS Framework
# 3     RBI                 RBI - CS Framework
# 4     RBI                 RBI - CS Framework
# ..    ...                                ...
# 81    RBI  RBI - CS, Third Party, ASP - 2019
# 82    RBI               RBI - CS, PCB - 2018
# 83    RBI               RBI - CS, PCB - 2018
# 84    RBI               RBI - CS, PCB - 2018
# 85    RBI               RBI - CS, PCB - 2018
#
# [86 rows x 9 columns]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download NLTK stopwords (you only need to do this once)
nltk.download('stopwords')

# Define a function for text cleaning
def clean_text(text):
    # Tokenize the text
    words = word_tokenize(text)
    
    # Remove punctuation and convert to lowercase
    words = [word.lower() for word in words if word.isalnum()]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    # Join the words back into a clean text
    clean_text = ' '.join(words)
    
    return clean_text

# Apply the clean_text function to your Requirement Description column
df['Cleaned_Description'] = df['Requirement Description'].apply(clean_text)


# Configure pandas to display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Configure pandas to display the entire column content
pd.set_option('display.max_colwidth', None)

# Print the entire DataFrame to check the results
print(df['Cleaned_Description'])
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       information security across stages application life cycle
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            respect critical business applications banks may consider conducting source code audits professionally competent providers assurance application application free embedded malicious fraudulent code
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  secure coding practices may also implemented internally developed applications
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                        besides business functionalities security requirements relating system access control authentication transaction authorization data integrity system activity logging audit trail session management security event tracking exception handling required clearly specified initial ongoing stages system
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               development test production environments need properly segregated
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     development approach based threat modelling
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             development approach based secure coding principles
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         development approach incorporate security testing based global standards secure rollout
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ensure development practices addresses vulnerabilities based best practices baselines open web application security project owasp proactively adopt principle provide layered security mechanism
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       consider implementing measures installing containerized apps phones exclusive business use encrypted separated smartphone
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           consider implementing measures initiate remote wipe containerized app rendering data unreadable case requirement may also considered
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ensure adoption new technologies shall adequately evaluated security threats team bank reach reasonable level comfort maturity technologies introducing critical systems bank
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             res shall implement application architecture segregating application database presentation layer digital payment products services
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          res shall follow secure design approach development digital payment products services res shall ensure digital payment applications inherently secure embedding security within development lifecycle
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         res shall explicitly define security objectives including protection customer data requirements gathering b designing c development testing including source code review e implementation maintenance monitoring f decommissioning phases digital payment applications
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     res including partnering entities applications shall adopt incorporate threat modelling approach application lifecycle management policies processes guidelines procedures
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    digital payment applications licensed third party vendor res shall escrow arrangement source code ensuring continuity services case vendor defaults unable provide services
# 17                                                                                                                                                                                                                                                                                       res shall conduct security testing including review source code vulnerability assessment va penetration testing pt digital payment applications assure application secure putting transactions preserving confidentiality integrity data stored transmitted testing invariably cover compliance various standards like owasp source code owned cases shall obtain certificate application developer stating application free known vulnerabilities malwares covert channels code context
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            res may also run automated va scanning tools automatically scan systems network critical public facing store customer sensitive data frequent basis
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    res shall compare results earlier vulnerability scans ascertain vulnerabilities addressed either patching implementing compensating control documenting accepting residual risk necessary approval recurrence known vulnerabilities identified vulnerabilities fixed manner
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             res shall ensure vulnerability scanning performed authenticated mode either agents running locally system analyse security configuration remote scanners given administrative rights system tested
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               res shall verify thoroughly test functionality validate whether system meets functional specifications security controls payment products services moving production environment
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   res shall institute mechanism actively monitor malicious applications similar features popular web respond accordingly bring
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      server end adequate checks balances ensure transaction carried unauthorised digital payment applications authentication process robust secure centralised
# 24                                                                                                                                                                                                                  security controls digital payment applications must focus applications handle store protect payment data apis secure data storage communication implemented used correctly order effective res shall refer standards relevant owasp standards security data protection guidelines iso 12812 threat catalogues guides developed nist including bluetooth lte security application security protection measures testing necessarily verify vulnerabilities including limited owasp mobile top 10 application security requirements shared operating system oems
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         res shall mask customer information account card sensitive information transmitted via
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      periodically conduct vulnerability assessment penetration testing exercises critical systems particularly facing internet
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        vulnerabilities detected remedied promptly terms bank risk framework avoid exploitation vulnerabilities
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    penetration testing public facing systems well critical applications carried professionally qualified teams
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       findings follow actions necessitated monitored closely information technology audit team well management
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 automated vulnerability scanning tools need used systems networks periodic basis say monthly weekly frequently
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                   banks ensure vulnerability scanning performed authenticated mode configuring scanner administrator credentials least quarterly either agents running locally end system analyze security configuration remote scanners given administrative rights system tested overcome limitations unauthenticated vulnerability scanning
# 32                                                                                                                                                                                                                                                                                                                                                                                   banks compare results vulnerability scans verify vulnerabilities addressed either patching implementing compensating control documenting accepting reasonable business risk acceptance business risks existing vulnerabilities periodically reviewed determine newer compensating controls subsequent patches address vulnerabilities previously accepted conditions changed increasing risk
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      vulnerability scanning tools tuned compare services listening machine list authorized services tools tuned identify changes time systems authorized unauthorized services
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       security function updated status regarding numbers unmitigated critical vulnerabilities plan mitigation share vulnerability reports indicating critical issues senior management provide effective incentives mitigation
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    web applications providing digital payment products services store sensitive information html hidden fields cookies storage avoid compromise integrity data
# 36                                                                                                                                                                                                                                                                                                                        key length asymmetric encryption hashing algorithms encryption signing exchange keys creation message digest random number generators cipher suites digital certificates applicable protocols used transmission channels processing data authentication purpose shall strong adopting internationally accepted published standards demonstrated vulnerable configurations involved implementing controls general compliant extant instructions law land
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         develop comprehensive data prevention strategy safeguard sensitive including confidential business customer shall include protecting data processed end point devices data transmission well data stored servers digital stores whether online offline
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     develop data prevention strategy vendor managed facilities
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        banks need define implement procedures ensure integrity consistency data stored electronic form databases data warehouses data archives
# 40                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    data security theory seeks establish uniform requirements protection data elements ensure protection uniform within outside institution tools data classifications protection profiles used
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                                        policies regarding media handling disposal transit implemented enable use protection profiles otherwise mitigate risks data protection profiles used policies accomplish goal protection profiles deliver degree residual risk without regard whether information transit storage directly controlling data storage may
# 42        secure storage media controls could include physical environmental controls fire flood protection limiting access means like physical locks keypad passwords biometrics labelling logged access management establish access controls limit access media ensuring employees authorization access minimum data required perform responsibilities sensitive information system documentation application source code production transaction data extensive controls guard alteration integrity checkers cryptographic hashes furthermore policies minimize distribution sensitive information including printouts contain information periodically security staff audit staff data owners review authorization levels distribution lists ensure remain appropriate current
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                storage data portable devices laptops pdas poses unique problems mitigation risks typically involves encryption sensitive data hostprovided access controls etc
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                              banks need appropriate disposal procedures electronic paper based media contracts disposal firms address acceptable disposal procedures computer media data frequently remains media erasure since data recovered additional disposal techniques applied sensitive data like physical destruction overwriting data degaussing etc
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             banks maintain security media transit shared third parties policies include contractual requirements incorporate necessary controls restrictions carriers used procedures verify identity couriers
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 banks encrypt customer account transaction data transmitted transported delivered couriered external parties locations taking account intermediate junctures transit points source destination
# 47                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           aspects also needs considered include appropriate blocking filtering monitoring electronic mechanisms like printing monitoring unauthorised software hardware like password cracking software key loggers wireless access points etc
# 48    concerns need better control protect sensitive information given rise new set solutions aimed increasing enterprise ability protect information assets solutions vary capabilities methodologies collectively placed category known data leak prevention dlp provides comprehensive approach covering people processes systems identify monitor protect data use endpoint actions data motion network actions data rest data storage deep content inspection centralized management framework dlp solutions include suite technologies facilitate three key objectives locate catalogue sensitive information stored throughout enterprise monitor control movement sensitive information across enterprise networks monitor control movement sensitive information systems
# 49                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            prepare maintain network architecture diagram organisation level including networks
# 50                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             maintain inventory authorised devices connected bank network bank premises authorised devices enabling bank network bank may consider implementing solutions automate network discovery management
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ensure network devices configured appropriately periodically assess whether configurations appropriate desired level network security
# 52                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             put appropriate controls secure wireless local area networks wireless access points wireless client access systems
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          mechanisms identify authorised hardware mobile devices like laptops mobile phones tablets etc ensure provided connectivity meet security requirements prescribed bank
# 54                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                mechanism automatically identify unauthorised device connections bank network block connections
# 55                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 put place mechanism detect remedy unusual activities systems servers network devices endpoints
# 56                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              establish standard operating procedures sop major activities including connecting devices network
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          security operation centre monitor logs various network activities capability escalate abnormal undesirable activities
# 58                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             boundary defences properly configured firewalls proxies dmz perimeter networks network ips ids mechanism filter inbound outbound traffic put place
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        pso shall follow secure design approach development life cycle design development products services ensure security weaknesses introduced build process
# 60                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            pso shall implement application architecture ensures segregation database layer layers developing digital payment products services
# 61                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  aslc guidelines shall apply procured products services well pso shall escrow arrangement source code applications procured vendors ensure continuity services
# 62                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  pso shall put place comprehensive data leak prevention policy confidentiality integrity availability protection business customer information transit rest respect data available vendor managed facilities commensurate criticality sensitivity information held transmitted
# ...
# 66                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   maintain inventory authorised devices connected ucb network ucb premises related network devices ucb network
# 67                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             boundary defences properly configured firewalls proxies zone dmz perimeter networks intrusion prevention system ips detection system ids mechanism filter inbound outbound traffic shall put place
# 68                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             lan segments atm network different
# 69                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 put place mechanism detect remedy unusual activities systems servers network devices endpoints
# 70                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         firewall rules shall defined block unidentified outbound connections reverse tcp shells potential backdoor connections
# 71                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            prepare maintain network architecture diagram organisation level including networks
# 72                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 maintain inventory authorised devices connected asp network asp premises authorised devices enabling asp network asp may consider implementing solutions automate network discovery management
# 73                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           mechanisms identify authorised hardware mobile devices like laptops mobile phones tablets etc ensure provided connectivity meet security requirements prescribed asp
# 74                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ensure network devices configured appropriately periodically assessed ensure configurations securely maintained
# 75                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 default passwords network changed installation
# 76                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               infrastructure asp designed adequate network separation controls
# 77                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 mechanism automatically identify unauthorised device connections asp network block connections
# 78                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           boundary defences properly configured firewalls proxies zone dmz perimeter networks ips ids mechanism filter inbound outbound traffic must put place
# 79                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              establish standard operating procedures sop major activities including connecting devices network
# 80                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 put place mechanism detect remedy unusual activities systems servers network devices endpoints
# 81                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         firewall rules shall defined block unidentified outbound connections reverse tcp shells potential backdoor connections
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ensure network devices configured appropriately periodically assessed ensure configurations securely maintained
# 83                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 default passwords network changed installation
# 84                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             put appropriate controls secure wireless local area networks wireless access points wireless client access systems
# 85                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               critical infrastructure ucb neft rtgs swift cbs atm infrastructure designed adequate network separation controls
# Name: Cleaned_Description, dtype: object
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/PremGanesh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split

# Load your dataset
file_path = 'POC Based Requirements.xlsx'
df = pd.read_excel(file_path)

# Split the data into training (80%) and testing (20%) sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Print unique labels in the training set
unique_train_buckets = train_df['Requirements Bucket'].unique()
unique_train_areas = train_df['Requirement Area'].unique()

print("Unique Requirement Buckets in Training Set:")
print(unique_train_buckets)

print("\nUnique Requirement Areas in Training Set:")
print(unique_train_areas)

# Print unique labels in the testing set
unique_test_buckets = test_df['Requirements Bucket'].unique()
unique_test_areas = test_df['Requirement Area'].unique()

print("\nUnique Requirement Buckets in Testing Set:")
print(unique_test_buckets)

print("\nUnique Requirement Areas in Testing Set:")
print(unique_test_areas)
# Out:
# Unique Requirement Buckets in Training Set:
# ['unauthorised network' 'Network inventory Manangement'
#  'Third Party Software Evaluation' 'Vulnerability Scans'
#  'Data Classification' 'Security Testing'
#  'Containerized Mobile Applications' 'Data Storage' 'Threat Modelling'
#  'Secure Data Storage' 'Vulnerability Authenticated Scans'
#  'Client side Data storage' 'Data Transmission'
#  'Data Disposal and Deletion' 'Code Escrow' 'Data Storage/ Access Control'
#  'Vulnerability Management' 'network architecture'
#  'Network device management' 'Access control' 'Data Masking'
#  'Data monitoring' 'Secure SDLC Lifecycle' 'Secure Development Practices'
#  'Security Requirements' 'Third party Assessment'
#  'Wireless network security' 'Secure Coding Practices'
#  'Network Testing and Incident Response' 'Cryptographic security'
#  'Network Testing' 'Network seggregation' 'Data Encryption'
#  'Network security' 'Data Storage/ Encryption' 'Network monitoring'
#  'Data Protection Policies' 'Firewalls and intrusion detection'
#  'Data Loss Prevention' 'Network Assessment and network Logs'
#  'Vulnerability Remediation' 'Firewall management' 'Secure SDLC'
#  'Data Policies' 'Network Procedures' 'Third Party Code Audits'
#  'Application Testing' 'Unauthorised application check' 'Network testing'
#  'Secure Environment ' 'Network SLDC' 'Network Assessment']
#
# Unique Requirement Areas in Training Set:
# ['Network Management and Security' 'Network Management and \nSecurity'
#  'Application Security' 'Data Security']
#
# Unique Requirement Buckets in Testing Set:
# ['Access control' 'Secure SDLC Lifecycle' 'Wireless network security'
#  'Malicious Application Scanning' 'Secure Architecture'
#  'Network monitoring' 'Application Remove Wipe' 'Vulnerability Scans'
#  'Environment segregation' 'Firewalls and intrusion detection'
#  'Escrow Arrangement' 'Data Storage/ Transmission' 'Network security'
#  'Network Security' 'Data Loss Prevention' 'Inventory Management'
#  'Vulnerability Tools Tuning']
#
# Unique Requirement Areas in Testing Set:
# ['Network Management and \nSecurity' 'Application Security'
#  'Network Management and Security' 'Data Security']

# %%
from sklearn.preprocessing import LabelEncoder

# Create label encoders
bucket_encoder = LabelEncoder()
area_encoder = LabelEncoder()

# Fit and transform the training data
y_train_buckets = bucket_encoder.fit_transform(train_df['Requirements Bucket'])
y_train_areas = area_encoder.fit_transform(train_df['Requirement Area'])

# Transform the test data and handle unknown labels
y_test_buckets = bucket_encoder.transform(test_df['Requirements Bucket'])
y_test_areas = area_encoder.transform(test_df['Requirement Area'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/sklearn/utils/_encode.py:224, in _encode(values, uniques, check_unknown)
#     223 try:
# --> 224     return _map_to_integer(values, uniques)
#     225 except KeyError as e:
#
# File /usr/local/lib/python3.11/site-packages/sklearn/utils/_encode.py:164, in _map_to_integer(values, uniques)
#     163 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 164 return np.array([table[v] for v in values])
#
# File /usr/local/lib/python3.11/site-packages/sklearn/utils/_encode.py:164, in <listcomp>(.0)
#     163 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 164 return np.array([table[v] for v in values])
#
# File /usr/local/lib/python3.11/site-packages/sklearn/utils/_encode.py:158, in _nandict.__missing__(self, key)
#     157     return self.nan_value
# --> 158 raise KeyError(key)
#
# KeyError: 'Malicious Application Scanning'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 12
#       9 y_train_areas = area_encoder.fit_transform(train_df['Requirement Area'])
#      11 # Transform the test data and handle unknown labels
# ---> 12 y_test_buckets = bucket_encoder.transform(test_df['Requirements Bucket'])
#      13 y_test_areas = area_encoder.transform(test_df['Requirement Area'])
#
# File /usr/local/lib/python3.11/site-packages/sklearn/utils/_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File /usr/local/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:139, in LabelEncoder.transform(self, y)
#     136 if _num_samples(y) == 0:
#     137     return np.array([])
# --> 139 return _encode(y, uniques=self.classes_)
#
# File /usr/local/lib/python3.11/site-packages/sklearn/utils/_encode.py:226, in _encode(values, uniques, check_unknown)
#     224         return _map_to_integer(values, uniques)
#     225     except KeyError as e:
# --> 226         raise ValueError(f"y contains previously unseen labels: {str(e)}")
#     227 else:
#     228     if check_unknown:
#
# ValueError: y contains previously unseen labels: 'Malicious Application Scanning'
